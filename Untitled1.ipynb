# %%
import matplotlib.pyplot as plt
labels = 'Python', 'C++', 'Ruby', 'Java'
#Replace this with labels of crime
sizes = [215, 130, 245, 210]
#Replace this with # of people per crime
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice


plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %%
import numpy as np
vals = np.array([[1, 2, 3, 4], [2, 3, 4, 5], [3, 4, 5, 6]])
fig, ax = plt.subplots()
ax.pie(vals.flatten(), radius=1.2,
       colors=plt.rcParams["axes.prop_cycle"].by_key()["color"][:vals.shape[1]])
ax.pie(vals.sum(axis=1), radius=1)
ax.set(aspect="equal", title='Pie plot with `ax.pie`')

plt.show()

# %%
import datetime
import random
#import matplotlib.pyplot as plt

# make up some data
x = [datetime.datetime.now() + datetime.timedelta(hours=i) for i in range(12)]
y = [i+random.gauss(0,1) for i,_ in enumerate(x)]

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
print(x)
print(y)
# Out:
# [datetime.datetime(2018, 10, 26, 22, 47, 20, 590492), datetime.datetime(2018, 10, 26, 23, 47, 20, 590492), datetime.datetime(2018, 10, 27, 0, 47, 20, 590492), datetime.datetime(2018, 10, 27, 1, 47, 20, 590492), datetime.datetime(2018, 10, 27, 2, 47, 20, 590492), datetime.datetime(2018, 10, 27, 3, 47, 20, 590492), datetime.datetime(2018, 10, 27, 4, 47, 20, 590492), datetime.datetime(2018, 10, 27, 5, 47, 20, 590492), datetime.datetime(2018, 10, 27, 6, 47, 20, 590492), datetime.datetime(2018, 10, 27, 7, 47, 20, 590492), datetime.datetime(2018, 10, 27, 8, 47, 20, 590492), datetime.datetime(2018, 10, 27, 9, 47, 20, 590492)]
# [0.6364520303814737, 1.8767538989934227, 2.7217671192476165, 3.609096095992253, 2.8319236976881434, 5.613664406676919, 4.523265652307084, 8.179225718165984, 7.818104082009421, 9.786571865027017, 12.209826527029566, 11.36465773650007]

# %%
plt.clf()
# use keyword args

import datetime
import random
#import matplotlib.pyplot as plt
x = [1140,2302,600]
hour = []
for y in range(len(x)-1):
    hour.append(int(x[y])/100)
xAxis = [range(23)]
yAxis = []
for x in range(len(xAxis)):
    yAxis.append(xAxis.count(xAxis[x]))
# make up some data
#x = [datetime.datetime.now() + datetime.timedelta(hours=i) for i in range(12)]
#y = [i+random.gauss(0,1) for i,_ in enumerate(x)]

# plot
plt.setp(lines, color='r', linewidth=2.0)
# or MATLAB style string value pairs
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)

plt.plot(xAxis,yAxis)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ceab157f3dec> in <module>()
#      18
#      19 # plot
# ---> 20 plt.setp(lines, color='r', linewidth=2.0)
#      21 # or MATLAB style string value pairs
#      22 plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
#
# NameError: name 'lines' is not defined
